# %% [markdown]
# ### This notebook was created as a guided project in "Storytelling Through Data Visualization" course at DataQuest.io to visualize the gender gap in college degrees.
# <br>
# Data set can be downloaded from [here](http://www.randalolson.com/wp-content/uploads/percent-bachelors-degrees-women-usa.csv)

# %%
import numpy as np
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %%
lib_arts_cats = ['Art and Performance', 'Communications and Journalism',
                 'English', 'Foreign Languages',
                'Social Sciences and History']
union = list(set(stem_cats).union(lib_arts_cats))
other_cats = list(set(women_degrees.columns[1:].tolist()) - set(union))

# %%
fig = plt.figure(figsize=(28, 15))
for i in range(18):
    ax = fig.add_subplot(6,3,i+1)
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    if i in np.arange(0,16,3):
        ax.plot(women_degrees['Year'], women_degrees[stem_cats[int(i/3)]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[int(i/3)]], c=cb_orange, label='Men', linewidth=3)
        ax.set_title(stem_cats[int(i/3)])
        if i == 0:
            ax.text(2005, 87, 'Men')
            ax.text(2002, 8, 'Women')
        elif i == 15:
            ax.text(2005, 62, 'Men')
            ax.text(2001, 35, 'Women')
            ax.tick_params(labelbottom='on')
            
    elif i in np.arange(1,14,3):
        ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[int((i-1)/3)]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[int((i-1)/3)]], c=cb_orange, label='Men', linewidth=3)
        ax.set_title(lib_arts_cats[int((i-1)/3)])
        if i == 1:
            ax.text(2005, 87, 'Men')
            ax.text(2002, 8, 'Women')
        elif i == 13:
            ax.text(2005, 62, 'Men')
            ax.text(2001, 35, 'Women')
            ax.tick_params(labelbottom='on')
    elif i in np.arange(2,18,3):
        ax.plot(women_degrees['Year'], women_degrees[other_cats[int((i-2)/3)]], c=cb_dark_blue, label='Women', linewidth=3)
        ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[int((i-2)/3)]], c=cb_orange, label='Men', linewidth=3)
        ax.set_title(other_cats[int((i-2)/3)])
        if i == 2:
            ax.text(2005, 87, 'Men')
            ax.text(2002, 8, 'Women')
        elif i == 17:
            ax.text(2005, 62, 'Men')
            ax.text(2001, 35, 'Women')
            ax.tick_params(labelbottom='on')
        
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    
    
plt.show()
plt.savefig("gender_degrees.png")
